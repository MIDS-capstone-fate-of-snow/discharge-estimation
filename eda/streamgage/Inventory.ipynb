# %%
import datetime
import itertools
import os

import folium
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
DATA_DIR = os.path.join("..", "..", "data")

# %%
fp = os.path.join(DATA_DIR, "hydrograph-excel-sheet-tp-cleaned.xlsx")
xl = pd.ExcelFile(fp)
gages = [int(s) for s in xl.sheet_names]

# %%
fp = os.path.join(DATA_DIR, "inventory_clean")

# %%
inventory = pd.read_csv(fp, sep="\t")

# %%
target_gages = inventory[inventory["site_no"].isin(gages)]

# %%
# Define the center of our map.
center_lat, center_lon = 37.923161,-119.929827

my_map = folium.Map(location=[center_lat, center_lon], zoom_start=6)

for ix, row in target_gages.iterrows():
    lat, lon, name = row["dec_lat_va"], row["dec_long_va"], row["site_no"]
    folium.Marker(location=[lat, lon], 
                  radius=10, popup=f"{name} ({lat}, {lon})").add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db7363ba4a6c8045a5ac02b118a04c21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db7363ba4a6c8045a5ac02b118a04c21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_db7363ba4a6c8045a5ac02b118a04c21 = L.map(
#                 &quot;map_db7363ba4a6c8045a5ac02b118a04c21&quot;,
#                 {
#                     center: [37.923161, -119.929827],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b88f021012b1f5a7cf50157ad9de219b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#             var marker_17d5265f8a25f0d59e32461eacde99c1 = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#         var popup_d293f801961622f05e4b929f1b7f7a24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_638c60edee76b62c6494037ee27eb53b = $(`&lt;div id=&quot;html_638c60edee76b62c6494037ee27eb53b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_d293f801961622f05e4b929f1b7f7a24.setContent(html_638c60edee76b62c6494037ee27eb53b);
#
#
#         marker_17d5265f8a25f0d59e32461eacde99c1.bindPopup(popup_d293f801961622f05e4b929f1b7f7a24)
#         ;
#
#
#
#
#             var marker_4fbf6ea7ef1199b8bd9546aa31415f3f = L.marker(
#                 [35.7374516, -118.173689],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#         var popup_bf65331320a60fe7a42a30b492ad7132 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_30b5c26ffea83288db6e315636103ba0 = $(`&lt;div id=&quot;html_30b5c26ffea83288db6e315636103ba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11189500 (35.7374516, -118.173689)&lt;/div&gt;`)[0];
#             popup_bf65331320a60fe7a42a30b492ad7132.setContent(html_30b5c26ffea83288db6e315636103ba0);
#
#
#         marker_4fbf6ea7ef1199b8bd9546aa31415f3f.bindPopup(popup_bf65331320a60fe7a42a30b492ad7132)
#         ;
#
#
#
#
#             var marker_f0c1a46711d6da1e4e7a48bc2ea7b8ea = L.marker(
#                 [36.1613358, -118.7095358],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#         var popup_ccc6146c635d894524187aa3999d7f34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fe099ae7d978eb287b08d63eb18dde84 = $(`&lt;div id=&quot;html_fe099ae7d978eb287b08d63eb18dde84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11202710 (36.1613358, -118.7095358)&lt;/div&gt;`)[0];
#             popup_ccc6146c635d894524187aa3999d7f34.setContent(html_fe099ae7d978eb287b08d63eb18dde84);
#
#
#         marker_f0c1a46711d6da1e4e7a48bc2ea7b8ea.bindPopup(popup_ccc6146c635d894524187aa3999d7f34)
#         ;
#
#
#
#
#             var marker_7da7c2dd87b61a2bbab4563532d5e403 = L.marker(
#                 [36.5218899, -118.7992652],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#         var popup_1b2525f2613a0aec54ebfc71bbd580d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0d922558a1052f099a071c7c5141be3b = $(`&lt;div id=&quot;html_0d922558a1052f099a071c7c5141be3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11208000 (36.5218899, -118.7992652)&lt;/div&gt;`)[0];
#             popup_1b2525f2613a0aec54ebfc71bbd580d8.setContent(html_0d922558a1052f099a071c7c5141be3b);
#
#
#         marker_7da7c2dd87b61a2bbab4563532d5e403.bindPopup(popup_1b2525f2613a0aec54ebfc71bbd580d8)
#         ;
#
#
#
#
#             var marker_a021dcb6545f44ed2f1e3f8342e5fe75 = L.marker(
#                 [37.71687138, -119.6662788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8045a5ac02b118a04c21);
#
#
#         var popup_b6c825b3feb70ae961bf96454ec0e810 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_68cc61631d9567bca66d690be21c0a2a = $(`&lt;div id=&quot;html_68cc61631d9567bca66d690be21c0a2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11266500 (37.71687138, -119.6662788)&lt;/div&gt;`)[0];
#             popup_b6c825b3feb70ae961bf96454ec0e810.setContent(html_68cc61631d9567bca66d690be21c0a2a);
#
#
#         marker_a021dcb6545f44ed2f1e3f8342e5fe75.bindPopup(popup_b6c825b3feb70ae961bf96454ec0e810)
#         ;
#
#
#
#
#             var marker_d9dc834c7568e55d888076aebaf1a66a = L.marker(
#                 [38.36824625, -120.5454823],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_db7363ba4a6c8
