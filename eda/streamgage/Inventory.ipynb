# %%
import datetime
import itertools
import os

import folium
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
DATA_DIR = os.path.join("..", "..", "data")

# %%
fp = os.path.join(DATA_DIR, "hydrograph-excel-sheet-tp-cleaned.xlsx")
xl = pd.ExcelFile(fp)
gages = [int(s) for s in xl.sheet_names]

# %%
fp = os.path.join(DATA_DIR, "inventory_clean")

# %%
inventory = pd.read_csv(fp, sep="\t")

# %%
target_gages = inventory[inventory["site_no"].isin(gages)]

# %%
# Examples of the data for one of the gages:
target_gages.iloc[0]
# Out:
# agency_cd                                          USGS
# site_no                                        11185500
# station_nm               KERN R NO 3 CN NR KERNVILLE CA
# site_tp_cd                                           ST
# lat_va                                         355420.0
# long_va                                       1182800.0
# dec_lat_va                                    35.905504
# dec_long_va                                 -118.467586
# coord_meth_cd                                         M
# coord_acy_cd                                          F
# coord_datum_cd                                    NAD27
# dec_coord_datum_cd                                NAD83
# district_cd                                           6
# state_cd                                              6
# county_cd                                           107
# country_cd                                           US
# land_net_ds                                         NaN
# map_nm                                              NaN
# map_scale_fc                                        NaN
# alt_va                                              NaN
# alt_meth_cd                                         NaN
# alt_acy_va                                          NaN
# alt_datum_cd                                        NaN
# huc_cd                                       18030001.0
# basin_cd                                            NaN
# topo_cd                                             NaN
# data_types_cd            ANNNNNNNNNNNNNNNNNNNNNNNNNNNNI
# instruments_cd           NNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# construction_dt                                     NaN
# inventory_dt                                        NaN
# drain_area_va                                       NaN
# contrib_drain_area_va                               NaN
# tz_cd                                               PST
# local_time_fg                                         Y
# reliability_cd                                      NaN
# gw_file_cd                                     NYNNNNNN
# nat_aqfr_cd                                         NaN
# aqfr_cd                                             NaN
# aqfr_type_cd                                        NaN
# well_depth_va                                       NaN
# hole_depth_va                                       NaN
# depth_src_cd                                        NaN
# project_no                                          NaN
# rt_bol                                              0.0
# peak_begin_date                                      --
# peak_end_date                                        --
# peak_count_nu                                       0.0
# qw_begin_date                                        --
# qw_end_date                                          --
# qw_count_nu                                         0.0
# gw_begin_date                                        --
# gw_end_date                                          --
# gw_count_nu                                         0.0
# sv_begin_date                                2008-05-13
# sv_end_date                                  2022-04-28
# sv_count_nu                                        33.0
# Name: 1700, dtype: object

# %%
# Define the center of our map.
center_lat, center_lon = 37.923161,-119.929827

my_map = folium.Map(location=[center_lat, center_lon], zoom_start=6)

for ix, row in target_gages.iterrows():
    lat, lon, name = row["dec_lat_va"], row["dec_long_va"], row["site_no"]
    folium.Marker(location=[lat, lon], 
                  radius=10, popup=f"{name} ({lat}, {lon})").add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df6397cc03d492769917d7a727c2c6a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df6397cc03d492769917d7a727c2c6a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_df6397cc03d492769917d7a727c2c6a5 = L.map(
#                 &quot;map_df6397cc03d492769917d7a727c2c6a5&quot;,
#                 {
#                     center: [37.923161, -119.929827],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ce692a6a1169a5e3d98a2080b78737f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#             var marker_b1bd06a677633bb2e8a0dca2a83abab4 = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#         var popup_c5a37170544d14b012ce45cd94dc2ffd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d5a86efe49c8ef96ad253207ab93f404 = $(`&lt;div id=&quot;html_d5a86efe49c8ef96ad253207ab93f404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_c5a37170544d14b012ce45cd94dc2ffd.setContent(html_d5a86efe49c8ef96ad253207ab93f404);
#
#
#         marker_b1bd06a677633bb2e8a0dca2a83abab4.bindPopup(popup_c5a37170544d14b012ce45cd94dc2ffd)
#         ;
#
#
#
#
#             var marker_f3ecb41cbdf5b5994fceda5adca6f74d = L.marker(
#                 [35.7374516, -118.173689],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#         var popup_41b2b3406463661fda36a476d85db6f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5f93d471e273476fae06b32bd3e8204 = $(`&lt;div id=&quot;html_f5f93d471e273476fae06b32bd3e8204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11189500 (35.7374516, -118.173689)&lt;/div&gt;`)[0];
#             popup_41b2b3406463661fda36a476d85db6f3.setContent(html_f5f93d471e273476fae06b32bd3e8204);
#
#
#         marker_f3ecb41cbdf5b5994fceda5adca6f74d.bindPopup(popup_41b2b3406463661fda36a476d85db6f3)
#         ;
#
#
#
#
#             var marker_ee934603728b2ccbf4505f10d6655bdb = L.marker(
#                 [36.1613358, -118.7095358],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#         var popup_72c6c118855d9025ad6ea7dccba5c231 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_941c6ba1f948874dcf9127a45c15ae4e = $(`&lt;div id=&quot;html_941c6ba1f948874dcf9127a45c15ae4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11202710 (36.1613358, -118.7095358)&lt;/div&gt;`)[0];
#             popup_72c6c118855d9025ad6ea7dccba5c231.setContent(html_941c6ba1f948874dcf9127a45c15ae4e);
#
#
#         marker_ee934603728b2ccbf4505f10d6655bdb.bindPopup(popup_72c6c118855d9025ad6ea7dccba5c231)
#         ;
#
#
#
#
#             var marker_24835ecf805347416783471bcfada55e = L.marker(
#                 [36.5218899, -118.7992652],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#         var popup_d017040c29b562515a4d3558e681429e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b38b5f0d9418a02d292a4cd31d161f13 = $(`&lt;div id=&quot;html_b38b5f0d9418a02d292a4cd31d161f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11208000 (36.5218899, -118.7992652)&lt;/div&gt;`)[0];
#             popup_d017040c29b562515a4d3558e681429e.setContent(html_b38b5f0d9418a02d292a4cd31d161f13);
#
#
#         marker_24835ecf805347416783471bcfada55e.bindPopup(popup_d017040c29b562515a4d3558e681429e)
#         ;
#
#
#
#
#             var marker_0d38c7f472e110e7913cffb7a910bd82 = L.marker(
#                 [37.71687138, -119.6662788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d492769917d7a727c2c6a5);
#
#
#         var popup_04205651ea751e6973b365fe9c5d41ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cc7cbb18779cb466b4c32dca8aa633fc = $(`&lt;div id=&quot;html_cc7cbb18779cb466b4c32dca8aa633fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11266500 (37.71687138, -119.6662788)&lt;/div&gt;`)[0];
#             popup_04205651ea751e6973b365fe9c5d41ff.setContent(html_cc7cbb18779cb466b4c32dca8aa633fc);
#
#
#         marker_0d38c7f472e110e7913cffb7a910bd82.bindPopup(popup_04205651ea751e6973b365fe9c5d41ff)
#         ;
#
#
#
#
#             var marker_4f2d094d803db0ab05cf8f73529cc0e2 = L.marker(
#                 [38.36824625, -120.5454823],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_df6397cc03d49

# %%
# Different types of sites in the dataset. What are these?
inventory["site_tp_cd"].value_counts()
# Out:
# GW         77949
# ST          6538
# LK          1064
# SP           978
# GW-TH        618
# SB-UZ        276
# SB-GWD       232
# GW-HZ        208
# FA-DV        206
# AT           206
# ES           206
# WE           157
# ST-CA         69
# AW            58
# SB-TSM        53
# LA-SH         53
# LA            47
# GW-CR         45
# FA-OF         44
# ST-DCH        44
# LA-OU         41
# FA-WWTP       38
# GW-MW         34
# OC-CO         24
# FA-WTP        20
# LA-EX         17
# FA-WWD        16
# GW-EX         13
# FA-WU         10
# FA-SPS         7
# FA-STS         5
# FA-WDS         5
# FA-WIW         5
# FA-QC          4
# GW-IW          4
# ST-TS          3
# SB             3
# FA-SEW         3
# FA-CI          2
# FA-PV          1
# LA-PLY         1
# LA-VOL         1
# Name: site_tp_cd, dtype: int64
