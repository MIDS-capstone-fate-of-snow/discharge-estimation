# %%
import datetime
import itertools
import os

import folium
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
DATA_DIR = os.path.join("..", "..", "data")

# %%
fp = os.path.join(DATA_DIR, "hydrograph-excel-sheet-tp-cleaned.xlsx")
xl = pd.ExcelFile(fp)
gages = [int(s) for s in xl.sheet_names]

# %%
inventory_fp = os.path.join(DATA_DIR, "inventory_clean")
inventory = pd.read_csv(inventory_fp, sep="\t")
target_gages = inventory[inventory["site_no"].isin(gages)]

# %%
# Examples of the data for one of the gages:
target_gages.iloc[0]
# Out:
# agency_cd                                          USGS
# site_no                                        11185500
# station_nm               KERN R NO 3 CN NR KERNVILLE CA
# site_tp_cd                                           ST
# lat_va                                         355420.0
# long_va                                       1182800.0
# dec_lat_va                                    35.905504
# dec_long_va                                 -118.467586
# coord_meth_cd                                         M
# coord_acy_cd                                          F
# coord_datum_cd                                    NAD27
# dec_coord_datum_cd                                NAD83
# district_cd                                           6
# state_cd                                              6
# county_cd                                           107
# country_cd                                           US
# land_net_ds                                         NaN
# map_nm                                              NaN
# map_scale_fc                                        NaN
# alt_va                                              NaN
# alt_meth_cd                                         NaN
# alt_acy_va                                          NaN
# alt_datum_cd                                        NaN
# huc_cd                                       18030001.0
# basin_cd                                            NaN
# topo_cd                                             NaN
# data_types_cd            ANNNNNNNNNNNNNNNNNNNNNNNNNNNNI
# instruments_cd           NNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# construction_dt                                     NaN
# inventory_dt                                        NaN
# drain_area_va                                       NaN
# contrib_drain_area_va                               NaN
# tz_cd                                               PST
# local_time_fg                                         Y
# reliability_cd                                      NaN
# gw_file_cd                                     NYNNNNNN
# nat_aqfr_cd                                         NaN
# aqfr_cd                                             NaN
# aqfr_type_cd                                        NaN
# well_depth_va                                       NaN
# hole_depth_va                                       NaN
# depth_src_cd                                        NaN
# project_no                                          NaN
# rt_bol                                              0.0
# peak_begin_date                                      --
# peak_end_date                                        --
# peak_count_nu                                       0.0
# qw_begin_date                                        --
# qw_end_date                                          --
# qw_count_nu                                         0.0
# gw_begin_date                                        --
# gw_end_date                                          --
# gw_count_nu                                         0.0
# sv_begin_date                                2008-05-13
# sv_end_date                                  2022-04-28
# sv_count_nu                                        33.0
# Name: 1700, dtype: object

# %%
# Define the center of our map.
center_lat, center_lon = 37.923161,-119.929827

my_map = folium.Map(location=[center_lat, center_lon], zoom_start=6)

for ix, row in target_gages.iterrows():
    lat, lon, name = row["dec_lat_va"], row["dec_long_va"], row["site_no"]
    folium.Marker(location=[lat, lon], 
                  radius=10, popup=f"{name} ({lat}, {lon})").add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5087acea253f46e826dc48ae15bd72ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5087acea253f46e826dc48ae15bd72ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5087acea253f46e826dc48ae15bd72ba = L.map(
#                 &quot;map_5087acea253f46e826dc48ae15bd72ba&quot;,
#                 {
#                     center: [37.923161, -119.929827],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad177b450f3f13e7a29c918776e22009 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#             var marker_c81917bbf81a0582450a689d69f1b8fc = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#         var popup_2213de904a44d0a58b2ecb3d22b27b16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2d181b9c71311311b7b007284056a100 = $(`&lt;div id=&quot;html_2d181b9c71311311b7b007284056a100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_2213de904a44d0a58b2ecb3d22b27b16.setContent(html_2d181b9c71311311b7b007284056a100);
#
#
#         marker_c81917bbf81a0582450a689d69f1b8fc.bindPopup(popup_2213de904a44d0a58b2ecb3d22b27b16)
#         ;
#
#
#
#
#             var marker_fe9ac189660baa39b4449cd25d20f9b6 = L.marker(
#                 [35.7374516, -118.173689],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#         var popup_6be38230282250df8b2e84362fa3c34a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f57a53874a7a65223c7d4010da7702ee = $(`&lt;div id=&quot;html_f57a53874a7a65223c7d4010da7702ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11189500 (35.7374516, -118.173689)&lt;/div&gt;`)[0];
#             popup_6be38230282250df8b2e84362fa3c34a.setContent(html_f57a53874a7a65223c7d4010da7702ee);
#
#
#         marker_fe9ac189660baa39b4449cd25d20f9b6.bindPopup(popup_6be38230282250df8b2e84362fa3c34a)
#         ;
#
#
#
#
#             var marker_ee7d8576a74b16c587fbaee816fc979e = L.marker(
#                 [36.1613358, -118.7095358],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#         var popup_0a39e613bd5d013e978df81513dec1e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6163f081c4e55a442120604545d960df = $(`&lt;div id=&quot;html_6163f081c4e55a442120604545d960df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11202710 (36.1613358, -118.7095358)&lt;/div&gt;`)[0];
#             popup_0a39e613bd5d013e978df81513dec1e9.setContent(html_6163f081c4e55a442120604545d960df);
#
#
#         marker_ee7d8576a74b16c587fbaee816fc979e.bindPopup(popup_0a39e613bd5d013e978df81513dec1e9)
#         ;
#
#
#
#
#             var marker_99c215e84c7b36797a1b6aaae9709bbf = L.marker(
#                 [36.5218899, -118.7992652],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#         var popup_332ae697baaa8c5700f47fc8f13d1dba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_21d3694fa420e3c5cc271ea4059909ca = $(`&lt;div id=&quot;html_21d3694fa420e3c5cc271ea4059909ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11208000 (36.5218899, -118.7992652)&lt;/div&gt;`)[0];
#             popup_332ae697baaa8c5700f47fc8f13d1dba.setContent(html_21d3694fa420e3c5cc271ea4059909ca);
#
#
#         marker_99c215e84c7b36797a1b6aaae9709bbf.bindPopup(popup_332ae697baaa8c5700f47fc8f13d1dba)
#         ;
#
#
#
#
#             var marker_908e880dae60e2bc81fac0a059ff4374 = L.marker(
#                 [37.71687138, -119.6662788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f46e826dc48ae15bd72ba);
#
#
#         var popup_9d516b32aa68590a73e6364cc31d0220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ac0815904f84c18f188ca6c05216388 = $(`&lt;div id=&quot;html_6ac0815904f84c18f188ca6c05216388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11266500 (37.71687138, -119.6662788)&lt;/div&gt;`)[0];
#             popup_9d516b32aa68590a73e6364cc31d0220.setContent(html_6ac0815904f84c18f188ca6c05216388);
#
#
#         marker_908e880dae60e2bc81fac0a059ff4374.bindPopup(popup_9d516b32aa68590a73e6364cc31d0220)
#         ;
#
#
#
#
#             var marker_0df37b24e8a5ca2c6caf1e5a2a212cff = L.marker(
#                 [38.36824625, -120.5454823],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_5087acea253f4

# %%
# Different types of sites in the dataset. What are these?
inventory["site_tp_cd"].value_counts()
# Out:
# GW         77949
# ST          6538
# LK          1064
# SP           978
# GW-TH        618
# SB-UZ        276
# SB-GWD       232
# GW-HZ        208
# FA-DV        206
# AT           206
# ES           206
# WE           157
# ST-CA         69
# AW            58
# SB-TSM        53
# LA-SH         53
# LA            47
# GW-CR         45
# FA-OF         44
# ST-DCH        44
# LA-OU         41
# FA-WWTP       38
# GW-MW         34
# OC-CO         24
# FA-WTP        20
# LA-EX         17
# FA-WWD        16
# GW-EX         13
# FA-WU         10
# FA-SPS         7
# FA-STS         5
# FA-WDS         5
# FA-WIW         5
# FA-QC          4
# GW-IW          4
# ST-TS          3
# SB             3
# FA-SEW         3
# FA-CI          2
# FA-PV          1
# LA-PLY         1
# LA-VOL         1
# Name: site_tp_cd, dtype: int64
