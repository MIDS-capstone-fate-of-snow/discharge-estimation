# %% [markdown]
# # Streamgage Drainage Basins

# %%
import os
import sys

import folium
import geopandas as gpd
import pandas as pd

sys.path.append(os.path.join("..", "..", "code"))
from usgs_drainage_areas import USGSDrainageArea


DATA_DIR = os.path.join("..", "..", "data")

gages = pd.read_csv(os.path.join(DATA_DIR, "target_gages.csv"), encoding="utf-8")
gages = gages.set_index(["site_no"])

# %%
def map_streamgage(lat: float, lon: float, gage_name: str = None, zoom_start: int = 5):
    """Map a streamgage."""
    if gage_name is None:
        gage_name = "Streamgage"
    my_map = folium.Map(location=[lat, lon], zoom_start=zoom_start, width="80%", height="100%")
    folium.Marker(location=[lat, lon], 
                  radius=10, popup=f"{gage_name} ({lat}, {lon})").add_to(my_map)
    return my_map

# %%
gage = gages.iloc[0]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11185500
# lat = 35.90550439, lon = -118.467586
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ae40019f0250c3e9d285618cd5380e {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ae40019f0250c3e9d285618cd5380e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74ae40019f0250c3e9d285618cd5380e = L.map(
#                 &quot;map_74ae40019f0250c3e9d285618cd5380e&quot;,
#                 {
#                     center: [35.90550439, -118.467586],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d14983da83fcc2bfefadd21fad2c469 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ae40019f0250c3e9d285618cd5380e);
#
#
#             var marker_26d89e9ff9c1ac406b6358cccd685d61 = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_74ae40019f0250c3e9d285618cd5380e);
#
#
#         var popup_99e238e01d03fc21053795e377d4d7e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e7c664a48a93987e48d74a52ca1df785 = $(`&lt;div id=&quot;html_e7c664a48a93987e48d74a52ca1df785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_99e238e01d03fc21053795e377d4d7e9.setContent(html_e7c664a48a93987e48d74a52ca1df785);
#
#
#         marker_26d89e9ff9c1ac406b6358cccd685d61.bindPopup(popup_99e238e01d03fc21053795e377d4d7e9)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gage = gages.iloc[1]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11189500
# lat = 35.7374516, lon = -118.173689
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1225f8b6a4b7e42c530945b56599d08c {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1225f8b6a4b7e42c530945b56599d08c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1225f8b6a4b7e42c530945b56599d08c = L.map(
#                 &quot;map_1225f8b6a4b7e42c530945b56599d08c&quot;,
#                 {
#                     center: [35.7374516, -118.173689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4a3fa0fdbaa2278962f195e98d1a57c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1225f8b6a4b7e42c530945b56599d08c);
#
#
#             var marker_fdfc7f8419ec11805fcf023b224c804c = L.marker(
#                 [35.7374516, -118.173689],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_1225f8b6a4b7e42c530945b56599d08c);
#
#
#         var popup_9f120a5f290126f0eb401f2aae034f24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_86693e56297b3c04fe27c4dedb5a1b3e = $(`&lt;div id=&quot;html_86693e56297b3c04fe27c4dedb5a1b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11189500 (35.7374516, -118.173689)&lt;/div&gt;`)[0];
#             popup_9f120a5f290126f0eb401f2aae034f24.setContent(html_86693e56297b3c04fe27c4dedb5a1b3e);
#
#
#         marker_fdfc7f8419ec11805fcf023b224c804c.bindPopup(popup_9f120a5f290126f0eb401f2aae034f24)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gage = gages.iloc[2]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11202710
# lat = 36.1613358, lon = -118.7095358
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8668f788bc6a26eaa783a91f4939b8e1 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8668f788bc6a26eaa783a91f4939b8e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8668f788bc6a26eaa783a91f4939b8e1 = L.map(
#                 &quot;map_8668f788bc6a26eaa783a91f4939b8e1&quot;,
#                 {
#                     center: [36.1613358, -118.7095358],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb34eb6ddee27bee77451d07a2ca8f29 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8668f788bc6a26eaa783a91f4939b8e1);
#
#
#             var marker_2d878de3bfda4e52249eebb5f84eafd8 = L.marker(
#                 [36.1613358, -118.7095358],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_8668f788bc6a26eaa783a91f4939b8e1);
#
#
#         var popup_db176f92678d9b9278c6db10c8b03656 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_81e29bbaf236d505f95512406de47efa = $(`&lt;div id=&quot;html_81e29bbaf236d505f95512406de47efa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11202710 (36.1613358, -118.7095358)&lt;/div&gt;`)[0];
#             popup_db176f92678d9b9278c6db10c8b03656.setContent(html_81e29bbaf236d505f95512406de47efa);
#
#
#         marker_2d878de3bfda4e52249eebb5f84eafd8.bindPopup(popup_db176f92678d9b9278c6db10c8b03656)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gage = gages.iloc[3]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11208000
# lat = 36.5218899, lon = -118.7992652
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8e2174f479a3b8b46774abd6bcc25a6 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8e2174f479a3b8b46774abd6bcc25a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d8e2174f479a3b8b46774abd6bcc25a6 = L.map(
#                 &quot;map_d8e2174f479a3b8b46774abd6bcc25a6&quot;,
#                 {
#                     center: [36.5218899, -118.7992652],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_745f322c5efb356008ac232faaeb28a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8e2174f479a3b8b46774abd6bcc25a6);
#
#
#             var marker_beb89617308a4dc718379ea6ae0f7e2e = L.marker(
#                 [36.5218899, -118.7992652],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_d8e2174f479a3b8b46774abd6bcc25a6);
#
#
#         var popup_62a2d6eadcca3c269b80406a5f5abb54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1ab7766297f58d82c5ecffb415fb6061 = $(`&lt;div id=&quot;html_1ab7766297f58d82c5ecffb415fb6061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11208000 (36.5218899, -118.7992652)&lt;/div&gt;`)[0];
#             popup_62a2d6eadcca3c269b80406a5f5abb54.setContent(html_1ab7766297f58d82c5ecffb415fb6061);
#
#
#         marker_beb89617308a4dc718379ea6ae0f7e2e.bindPopup(popup_62a2d6eadcca3c269b80406a5f5abb54)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Streamgage 11266500

# %%
gage = gages.iloc[4]
fp = os.path.join(DATA_DIR, "usgs_basins", "11266500.geojson")
drainage_area = USGSDrainageArea(fp)
drainage_area.fmap()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e032fb0e47cea39ca07a56b926e3eb1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e032fb0e47cea39ca07a56b926e3eb1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e032fb0e47cea39ca07a56b926e3eb1a = L.map(
#                 &quot;map_e032fb0e47cea39ca07a56b926e3eb1a&quot;,
#                 {
#                     center: [37.716493670036186, -119.66647700370862],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_893cf6cfbfc1207048f3b19d5035693a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e032fb0e47cea39ca07a56b926e3eb1a);
#
#
#             var marker_f5a101266c929e412d9fb091ef06f9c0 = L.marker(
#                 [37.716493670036186, -119.66647700370862],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_e032fb0e47cea39ca07a56b926e3eb1a);
#
#
#         var popup_3026a1f599e4e878e45b57a55d085e58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_38841bde949866f2a2f9bf2e74dd9d37 = $(`&lt;div id=&quot;html_38841bde949866f2a2f9bf2e74dd9d37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=37.716493670036186, lon=-119.66647700370862&lt;/div&gt;`)[0];
#             popup_3026a1f599e4e878e45b57a55d085e58.setContent(html_38841bde949866f2a2f9bf2e74dd9d37);
#
#
#         marker_f5a101266c929e412d9fb091ef06f9c0.bindPopup(popup_3026a1f599e4e878e45b57a55d085e58)
#         ;
#
#
#
#
#         function geo_json_ac202fed06e863e92a8a07e9d76f89ac_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json
d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb98c7abe333a0c91de2635d9659c21b);
#
#
#             var marker_cd7602801023ecc91c2ef8d106fc1bdb = L.marker(
#                 [37.71687138, -119.6662788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_cb98c7abe333a0c91de2635d9659c21b);
#
#
#         var popup_0e0ab3b0d1ed813dbde66c5f7aa1975b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c4edeee33d62a4d57ae2c6486b7f0947 = $(`&lt;div id=&quot;html_c4edeee33d62a4d57ae2c6486b7f0947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11266500 (37.71687138, -119.6662788)&lt;/div&gt;`)[0];
#             popup_0e0ab3b0d1ed813dbde66c5f7aa1975b.setContent(html_c4edeee33d62a4d57ae2c6486b7f0947);
#
#
#         marker_cd7602801023ecc91c2ef8d106fc1bdb.bindPopup(popup_0e0ab3b0d1ed813dbde66c5f7aa1975b)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gage = gages.iloc[5]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11318500
# lat = 38.36824625, lon = -120.5454823
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5f3aef04a481bb85448b4d08fd3d833 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5f3aef04a481bb85448b4d08fd3d833&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c5f3aef04a481bb85448b4d08fd3d833 = L.map(
#                 &quot;map_c5f3aef04a481bb85448b4d08fd3d833&quot;,
#                 {
#                     center: [38.36824625, -120.5454823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1265df48ec5f6cd8f3ed2bb29fcc286 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c5f3aef04a481bb85448b4d08fd3d833);
#
#
#             var marker_62e38f69b429410cde3939704cce9cb0 = L.marker(
#                 [38.36824625, -120.5454823],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_c5f3aef04a481bb85448b4d08fd3d833);
#
#
#         var popup_086a3c9a2e9157c7d1ac522eb99ee2dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f07e9493c5c596eb129344bfa319ac2f = $(`&lt;div id=&quot;html_f07e9493c5c596eb129344bfa319ac2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11318500 (38.36824625, -120.5454823)&lt;/div&gt;`)[0];
#             popup_086a3c9a2e9157c7d1ac522eb99ee2dd.setContent(html_f07e9493c5c596eb129344bfa319ac2f);
#
#
#         marker_62e38f69b429410cde3939704cce9cb0.bindPopup(popup_086a3c9a2e9157c7d1ac522eb99ee2dd)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gage = gages.iloc[6]
print(f"Streamgage: {gage.name}")
print(f"lat = {gage['dec_lat_va']}, lon = {gage['dec_long_va']}")
map_streamgage(gage["dec_lat_va"], gage["dec_long_va"], gage.name, zoom_start=16)
# Out:
# Streamgage: 11402000
# lat = 40.002947, lon = -120.9543994
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c604c4d687f6a00cea497d65cba59416 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c604c4d687f6a00cea497d65cba59416&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c604c4d687f6a00cea497d65cba59416 = L.map(
#                 &quot;map_c604c4d687f6a00cea497d65cba59416&quot;,
#                 {
#                     center: [40.002947, -120.9543994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daaed9ef1e5b689943ecf3580ee370d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c604c4d687f6a00cea497d65cba59416);
#
#
#             var marker_08a110dcbdabb98480fdcdc0d3bea795 = L.marker(
#                 [40.002947, -120.9543994],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_c604c4d687f6a00cea497d65cba59416);
#
#
#         var popup_c0ee8a535dde833b1b820eccd51dbbd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_14fc641d4f2cea87e017505100c21b0a = $(`&lt;div id=&quot;html_14fc641d4f2cea87e017505100c21b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11402000 (40.002947, -120.9543994)&lt;/div&gt;`)[0];
#             popup_c0ee8a535dde833b1b820eccd51dbbd1.setContent(html_14fc641d4f2cea87e017505100c21b0a);
#
#
#         marker_08a110dcbdabb98480fdcdc0d3bea795.bindPopup(popup_c0ee8a535dde833b1b820eccd51dbbd1)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
