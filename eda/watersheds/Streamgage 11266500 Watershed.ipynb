# %% [markdown]
# # Streamgage 11266500 Watershed

# %%
import json
import os
import pickle
import sys
import time

import folium
import pandas as pd
import rasterio

sys.path.append(os.path.join("..", "..", "code"))
from google_helper_functions import (
    authenticate_gee, connect_to_service_account_gdrive, download_files_from_gdrive
)
from identify_watersheds import map_elevation_point, save_gee_elv_to_drive, WatershedIdentifier
from utils import get_latest_streamgage_file, update_json


DATA_DIR = os.path.join("..", "..", "data")
gages = pd.read_csv(os.path.join(DATA_DIR, "target_gages.csv"), encoding="utf-8")

# %%
# Target gage for this notebook:
ix = 4

gage = gages.iloc[ix]
lat, lon = gage["dec_lat_va"], gage["dec_long_va"]
name = gage["site_no"]

# Load the adjusted lat-lon coordinates to move the gage location to the river:
with open(os.path.join(DATA_DIR, "adjusted_lat_lon.json"), "r") as f:
    ADJUSTED_LAT_LON = json.load(f)
adjusted_lat, adjusted_lon = ADJUSTED_LAT_LON[str(gage["site_no"])]

print(f"Streamgage: {name}")
print(f"Original lat, lon: {lat}, {lon}")
print(f"Adjusted lat, lon: {adjusted_lat}, {adjusted_lon}")
# Out:
# Streamgage: 11266500
# Original lat, lon: 37.71687138, -119.6662788
# Adjusted lat, lon: 37.71644138, -119.6657788

# %%
# Authenticate with service account:
service_acct = "capstone-gee-account@snow-capstone.iam.gserviceaccount.com"
keys = os.path.join(os.path.expanduser("~"), "snow-capstone-4a3c9603fcf0.json")
credentials = authenticate_gee(service_acct, keys)

# Alternative manual authentication method:
# ee.Authenticate()
# ee.Initialize()

# %%
# Plot the gage on an elevation map:
my_map = map_elevation_point(lat=lat, lon=lon, name=name, buffer=10_000, zoom_start=9)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7df7386be8110a3ee11348e59b1c307 {
#                     position: relative;
#                     width: 60.0%;
#                     height: 60.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7df7386be8110a3ee11348e59b1c307&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b7df7386be8110a3ee11348e59b1c307 = L.map(
#                 &quot;map_b7df7386be8110a3ee11348e59b1c307&quot;,
#                 {
#                     center: [37.71687138, -119.6662788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65f47b660e2c9468729b500752cafdd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7df7386be8110a3ee11348e59b1c307);
#
#
#             var tile_layer_04668e8c9018acdca2f30becffb06eef = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/82302bf76471cbc4d71eafdc4e3c615a-649d7b38f4e2db60f24c63fd5ca41114/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7df7386be8110a3ee11348e59b1c307);
#
#
#             var marker_141a2b2185bdefacecf96ef5bc91b713 = L.marker(
#                 [37.71687138, -119.6662788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_b7df7386be8110a3ee11348e59b1c307);
#
#
#         var popup_35d980037d293b0da3753fb42f1b23b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8dcc66711edf383fff2ad473b0e61eee = $(`&lt;div id=&quot;html_8dcc66711edf383fff2ad473b0e61eee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11266500 (37.71687138, -119.6662788)&lt;/div&gt;`)[0];
#             popup_35d980037d293b0da3753fb42f1b23b9.setContent(html_8dcc66711edf383fff2ad473b0e61eee);
#
#
#         marker_141a2b2185bdefacecf96ef5bc91b713.bindPopup(popup_35d980037d293b0da3753fb42f1b23b9)
#         ;
#
#
#
#
#
#         function geo_json_8e892f58000208b6ec9157637d9abe74_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8e892f58000208b6ec9157637d9abe74 = L.geoJson(null, {
#                 onEachFeature: geo_json_8e892f58000208b6ec9157637d9abe74_onEachFeature,
#
#         });
#
#         function geo_json_8e892f58000208b6ec9157637d9abe74_add (data) {
#             geo_json_8e892f58000208b6ec9157637d9abe74
#                 .addData(data)
#                 .addTo(map_b7df7386be8110a3ee11348e59b1c307);
#         }
#             geo_json_8e892f58000208b6ec9157637d9abe74_add({&quot;coordinates&quot;: [[[-119.66627880000001, 37.80686003951482], [-119.69809045819248, 37.803274219404884], [-119.72736125786513, 37.79280318678552], [-119.75175530552261, 37.77628311225097], [-119.76932946699444, 37.755032510392454], [-119.77868846018634, 37.73074618462212], [-119.77909477527726, 37.70535930412559], [-119.77052503948173, 37.68089275020644], [-119.75366907783622, 37.65929223209519], [-119.72987261875379, 37.642273982305525], [-119.70102894196303, 37.63118913294966], [-119.66942846848646, 37.62691726050249], [-119.63757816753363, 37.629797233731004], [-119.60800461949016, 37.63960060330544], [-119.58305560272944, 37.655549539351725], [-119.5647151636503, 37.67637796514823], [-119.55444628446341, 37.70043126169818], [-119.55307348147858, 37.725796939381276], [-119.56071496564125, 37.75045619771369], [-119.57677044626926, 37.77244452127867], [-119.59996641711632, 37.79000856293034], [-119.62845610564341, 37.80174667031158], [-119.65996658304367, 37.80672157018243], [-119.66627880000001, 37.80686003951482]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Export the geotiff to GDrive for the elevation image in the highlighted polygon:
task, filename = save_gee_elv_to_drive(lat, lon, name=name, buffer=10_000, scale=30)
while task.status()["state"] != "COMPLETED":
    time.sleep(1)
print("Complete")
# Out:
# Complete

# %%
# Download the file from G:Drive to a local copy:
drive = connect_to_service_account_gdrive(keys)
tif_dir = os.path.join(DATA_DIR, "gage_tiff_files")
local_files = download_files_from_gdrive(drive, filename, tif_dir, download_all=True)
tif_fp = local_files[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]

# %%
# Get the fp to the latest tif_fp (if the above cell wasn't run):
tif_dir = os.path.join(DATA_DIR, "gage_tiff_files")
tif_file = get_latest_streamgage_file(tif_dir, name)
tif_fp = os.path.join(tif_dir, tif_file)

# %%
# Inspect the raw TIF file:
from rasterio.plot import show

tif_data = rasterio.open(tif_fp)
show(tif_data, with_bounds=True)
# Out:
# <AxesSubplot:>

# %%
ws = WatershedIdentifier(tif_fp, adjusted_lat, adjusted_lon, min_acc=10)
# Out:
# /Users/tp/virtualenvs/discharge-estimation/lib/python3.9/site-packages/pysheds/io.py:142: UserWarning: No `nodata` value detected. Defaulting to 0.
#   warnings.warn('No `nodata` value detected. Defaulting to 0.')
# /Users/tp/virtualenvs/discharge-estimation/lib/python3.9/site-packages/pysheds/io.py:142: UserWarning: No `nodata` value detected. Defaulting to 0.
#   warnings.warn('No `nodata` value detected. Defaulting to 0.')
# /Users/tp/virtualenvs/discharge-estimation/lib/python3.9/site-packages/pysheds/io.py:142: UserWarning: No `nodata` value detected. Defaulting to 0.
#   warnings.warn('No `nodata` value detected. Defaulting to 0.')

# %%
ws.map_latlons(18)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de25b9bba3172862d36098cd24e3a38b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de25b9bba3172862d36098cd24e3a38b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_de25b9bba3172862d36098cd24e3a38b = L.map(
#                 &quot;map_de25b9bba3172862d36098cd24e3a38b&quot;,
#                 {
#                     center: [37.71644138, -119.6657788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2df126bb668512fa3a4b3276d2c86ab7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de25b9bba3172862d36098cd24e3a38b);
#
#
#             var marker_5c34d8f7bb6a83335862018d274d4d28 = L.marker(
#                 [37.71644138, -119.6657788],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_de25b9bba3172862d36098cd24e3a38b);
#
#
#             var icon_e84752d8b5dadf2102cda5b3b71c3ab1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c34d8f7bb6a83335862018d274d4d28.setIcon(icon_e84752d8b5dadf2102cda5b3b71c3ab1);
#
#
#         var popup_2ef343bd41ea5f12e4fe9f912452ea6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_62a5b554362498ea3e3c6d530f55e7d5 = $(`&lt;div id=&quot;html_62a5b554362498ea3e3c6d530f55e7d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ORIGINAL (37.71644138, -119.6657788)&lt;/div&gt;`)[0];
#             popup_2ef343bd41ea5f12e4fe9f912452ea6f.setContent(html_62a5b554362498ea3e3c6d530f55e7d5);
#
#
#         marker_5c34d8f7bb6a83335862018d274d4d28.bindPopup(popup_2ef343bd41ea5f12e4fe9f912452ea6f)
#         ;
#
#
#
#
#             var marker_bfdc71ab24f9383f0a2c4e12892d724c = L.marker(
#                 [37.71657568751382, -119.66610613354446],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_de25b9bba3172862d36098cd24e3a38b);
#
#
#             var icon_e58cb9a69a05d268299013ae46d8c30d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bfdc71ab24f9383f0a2c4e12892d724c.setIcon(icon_e58cb9a69a05d268299013ae46d8c30d);
#
#
#         var popup_fb9e90b198f8c1afac3b68f84decb2a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3086bd94105e6735f5fb14c11ff5f82d = $(`&lt;div id=&quot;html_3086bd94105e6735f5fb14c11ff5f82d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SNAPPED (37.71657568751382, -119.66610613354446)&lt;/div&gt;`)[0];
#             popup_fb9e90b198f8c1afac3b68f84decb2a4.setContent(html_3086bd94105e6735f5fb14c11ff5f82d);
#
#
#         marker_bfdc71ab24f9383f0a2c4e12892d724c.bindPopup(popup_fb9e90b198f8c1afac3b68f84decb2a4)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ws.summarize_catchment(30)
# Out:
# {'max_width_km': 1.02,
#  'max_height_km': 2.13,
#  'total_sq_m': 1374300.0,
#  'total_sq_km': 1.3742999999999999}

# %%
dem_fig = ws.plot_dem()

# %%
dem_c_map = ws.plot_catchment(base_map="dem")

# %%
fdir_map = ws.plot_catchment(base_map="fdir")

# %%
acc_map = ws.plot_catchment(base_map="acc")

# %%
cm = ws.plot_catchment(base_map=None, clipped=True)

# %%
clipped_dem_map = ws.plot_catchment(base_map="dem", clipped=True)

# %%
clipped_fdir_map = ws.plot_catchment(base_map="fdir", clipped=True)

# %%
clipped_acc_map = ws.plot_catchment(base_map="acc", clipped=True)

# %%
ws.clipped_grid.bbox
# Out:
# (-119.67499945485724,
#  37.697441571962074,
#  -119.66583663895922,
#  37.71657568751382)

# %%
# # Save the watershed and confirm it can be reloaded:
# pickled_fp = ws.save(os.path.join(DATA_DIR, "watersheds"), f"{name}")


# def pickle_load(fp: str):
#     with open(fp, "rb") as f:
#         return pickle.load(f)
    

# unpickled_ws = pickle_load(pickled_fp)
# unpickled_ws.summarize_catchment()

# %%
# If this is True, then it is possible the full watershed has not been found, 
# and the size of the image downloaded from GEE should be increased:
print(ws.catchment_touches_grid_edge)
# Out:
# False

# %%
# Save the bounding box:
if not ws.catchment_touches_grid_edge:
    fp = os.path.join(DATA_DIR, "watershed_bounding_boxes.json")
    update_json(fp, str(gage["site_no"]), ws.clipped_grid.bbox)
# Out:
# Updated JSON file ../../data/watershed_bounding_boxes.json:
#   key = 11266500
#   value = (-119.67499945485724, 37.697441571962074, -119.66583663895922, 37.71657568751382)

# %%
ws.summarize_catchment(30)
# Out:
# {'max_width_km': 1.02,
#  'max_height_km': 2.13,
#  'total_sq_m': 1374300.0,
#  'total_sq_km': 1.3742999999999999}
