# %% [markdown]
# # Identifying Streamgage Watersheds
#
# This notebook goes through how to identify watersheds at different scales for a target streamgage, by finding the geometries of the overlapping watersheds with the lat-long location of the gage.

# %%
import os
import warnings

import folium
import geopandas as gpd
from IPython.display import Image
import pandas as pd


DATA_DIR = os.path.join("..", "..", "data")

# %%
ca_fp = os.path.join(DATA_DIR, "NHD", "NHD_H_California_State_Shape", "Shape")
ca_shapefiles = list(filter(lambda s: s.endswith(".shp"), os.listdir(ca_fp)))
wbd_shapefiles = list(filter(lambda s: s.startswith("WBDHU"), ca_shapefiles))

# %%
# Read in the shape files for each HU level:
geo_dfs = dict()
for wbd_filename in wbd_shapefiles:
    fp = os.path.join(ca_fp, wbd_filename)
    gdf = gpd.read_file(fp)
    shapefile_name = wbd_filename.split(".")[0]
    gdf["shapefile_name"] = shapefile_name
    geo_dfs[shapefile_name] = gdf

# %%
# Combine all Geo dfs into one:
gdfs_list = list(geo_dfs.values())
gdf = gpd.GeoDataFrame(pd.concat(gdfs_list, ignore_index=True), 
                       crs=gdfs_list[0].crs)

# %%
# Get our target gage ids:
sg_df = pd.read_csv(os.path.join(DATA_DIR, "streamgage-full.csv"), encoding="utf-8")
gage_ids = sg_df["gage"].unique()

# %%
# Get the full metadata for each gage which includes lat-long:
inventory_fp = os.path.join(DATA_DIR, "inventory_clean")
inventory = pd.read_csv(inventory_fp, sep="\t")
target_gages = inventory[inventory["site_no"].isin(gage_ids)]

# %%
def get_streamgage_lat_long(gage_id: int):
    """For a streamgage ID, return the lat-long coordinates of its location."""
    s = target_gages.set_index("site_no").loc[gage_id]
    return s["dec_lat_va"], s["dec_long_va"]

# %%
get_streamgage_lat_long(11185500)
# Out:
# (35.90550439, -118.467586)

# %%
def get_lat_long_geometry(lat: float, long: float):
    """For a given lat-long coordinate, return the coordinate 
    as a shapely.geometry.point.Point in a geopandas.array.GeometryArray."""
    df = pd.DataFrame({"longitude": [long], "latitude": [lat]})
    geometry = gpd.points_from_xy(df["longitude"], df["latitude"], crs="EPSG:4326")
    return geometry

# %%
lat, long = get_streamgage_lat_long(11185500)
get_lat_long_geometry(lat, long)
# Out:
# <GeometryArray>
# [<shapely.geometry.point.Point object at 0x7fa887d16910>]
# Length: 1, dtype: geometry

# %%
def get_streamgage_overlapping_watersheds(gage_id: int):
    """For a given streamgage ID return all overlapping watershed geometries."""
    lat, long = get_streamgage_lat_long(gage_id)
    point = get_lat_long_geometry(lat, long)[0]
    gdf_subset = gdf[(gdf["geometry"].contains(point))]
    if not len(gdf_subset):
        warnings.warn(f"No overlapping watershed geometries found for gage_id: {gage_id}")
    return gdf_subset

# %%
get_streamgage_overlapping_watersheds(11185500)
# Out:
#                                        tnmid  \
# 5128  {170C1E37-852D-44C5-917D-AC6E0BED46B6}
# 5430  {CD96A6F3-D975-455A-9101-E8FB7C7AC555}
# 6450  {D924BD6E-507C-4E5B-A86C-DDDDE00752A5}
# 6458  {C7AD4655-6535-43A8-8E11-6F5A55DD8963}
# 6488  {91CB7D75-4CD6-4EC4-ACB5-8524A6DFB363}
#
#                                   metasource sourcedata  \
# 5128                                    None       None
# 5430                                    None       None
# 6450  {FE4AD22E-A115-40E4-9EC7-8497E5725E31}       None
# 6458  {31AC21ED-1551-431B-963A-63D44B9887E8}       None
# 6488  {31AC21ED-1551-431B-963A-63D44B9887E8}       None
#
#                                              sourceorig sourcefeat  \
# 5128                                               None       None
# 5430                                               None       None
# 6450  Natural Resources and Conservation Service and...       None
# 6458                             U.S. Geological Survey       None
# 6488                             U.S. Geological Survey       None
#
#         loaddate referenceg     areaacres   areasqkm       states  ...  \
# 5128  2012-06-11       None  6.991771e+05    2829.47           CA  ...
# 5430  2012-10-24       None  1.417586e+05     573.68           CA  ...
# 6450  2022-03-15       None  1.078924e+08  436625.32  CA,MX,NV,OR  ...
# 6458  2022-01-02       None  1.050134e+07   42497.47           CA  ...
# 6488  2022-01-02       None  1.050134e+07   42497.47           CA  ...
#
#      ObjectID                                           geometry  \
# 5128       64  POLYGON ((-118.40092 36.69851, -118.40006 36.6...
# 5430      226  POLYGON ((-118.33786 35.94061, -118.33747 35.9...
# 6450        4  MULTIPOLYGON (((-123.01418 37.94333, -123.0148...
# 6458        8  POLYGON ((-118.90461 37.20802, -118.90404 37.2...
# 6488       14  POLYGON ((-118.90461 37.20802, -118.90404 37.2...
#
#      shapefile_name      huc8       huc10  huc14  huc16  huc2    huc6  huc4
# 5128         WBDHU8  18030001         NaN    NaN    NaN   NaN     NaN   NaN
# 5430        WBDHU10       NaN  1803000106    NaN    NaN   NaN     NaN   NaN
# 6450         WBDHU2       NaN         NaN    NaN    NaN    18     NaN   NaN
# 6458         WBDHU6       NaN         NaN    NaN    NaN   NaN  180300   NaN
# 6488         WBDHU4       NaN         NaN    NaN    NaN   NaN     NaN  1803
#
# [5 rows x 29 columns]

# %%
def get_streamgage_watershed(gage_id: int, hu: int):
    """For a given streamgage ID and hydrological unit resolution,
    return the watershed geometry for that point."""
    lat, long = get_streamgage_lat_long(gage_id)
    geos = get_streamgage_overlapping_watersheds(gage_id)
    return geos[(geos["shapefile_name"].str.lower().str.endswith(f"hu{hu}"))]

# %%
gdf_subset = get_streamgage_watershed(11185500, 2)
gdf_subset
# Out:
#                                        tnmid  \
# 6450  {D924BD6E-507C-4E5B-A86C-DDDDE00752A5}
#
#                                   metasource sourcedata  \
# 6450  {FE4AD22E-A115-40E4-9EC7-8497E5725E31}       None
#
#                                              sourceorig sourcefeat  \
# 6450  Natural Resources and Conservation Service and...       None
#
#         loaddate referenceg     areaacres   areasqkm       states  ...  \
# 6450  2022-03-15       None  1.078924e+08  436625.32  CA,MX,NV,OR  ...
#
#      ObjectID                                           geometry  \
# 6450        4  MULTIPOLYGON (((-123.01418 37.94333, -123.0148...
#
#      shapefile_name huc8 huc10  huc14  huc16  huc2  huc6 huc4
# 6450         WBDHU2  NaN   NaN    NaN    NaN    18   NaN  NaN
#
# [1 rows x 29 columns]

# %%
def map_streamgage_watershed(gage_id: int, hu: int, zoom_start: int = 5):
    """Map a streamgage and the overlapping watershed at the given HU resolution."""
    lat, lon = get_streamgage_lat_long(gage_id)
    
    my_map = folium.Map(location=[lat, lon], zoom_start=zoom_start, width="80%", height="100%")
    folium.Marker(location=[lat, lon], 
                  radius=10, popup=f"{gage_id} ({lat}, {lon})").add_to(my_map)

    watershed = get_streamgage_watershed(gage_id, hu)
    if not len(watershed):
        warnings.warn(f"\n  No watershed found for HU{hu}")
    for _, r in watershed.iterrows():
        sim_geo = gpd.GeoSeries(r["geometry"]).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {"fillColor": "orange"})
        label = watershed.iloc[0]["shapefile_name"]
        folium.Popup(label).add_to(geo_j)
        geo_j.add_to(my_map)

    return my_map

# %%
map_streamgage_watershed(11185500, 2, 5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e3c285748037c431becb0ac08a2a82b {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e3c285748037c431becb0ac08a2a82b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1e3c285748037c431becb0ac08a2a82b = L.map(
#                 &quot;map_1e3c285748037c431becb0ac08a2a82b&quot;,
#                 {
#                     center: [35.90550439, -118.467586],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_458257d1c91b5d156745a463bb87dcdb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1e3c285748037c431becb0ac08a2a82b);
#
#
#             var marker_59f2b7a28d9a27c05d85dd19b6e81d96 = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_1e3c285748037c431becb0ac08a2a82b);
#
#
#         var popup_ff707266ca6177f0ea329fbf00c379db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3965630d6173b8504ab18fe5bd553742 = $(`&lt;div id=&quot;html_3965630d6173b8504ab18fe5bd553742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_ff707266ca6177f0ea329fbf00c379db.setContent(html_3965630d6173b8504ab18fe5bd553742);
#
#
#         marker_59f2b7a28d9a27c05d85dd19b6e81d96.bindPopup(popup_ff707266ca6177f0ea329fbf00c379db)
#         ;
#
#
#
#
#         function geo_json_e49be6249977326bfca691ebf2facfa0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_e49be6249977326bfca691ebf2facfa0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e49be6249977326bfca691ebf2facfa0 = L.geoJson(null, {
#                 onEachFeature: geo_json_e49be6249977326bfca691ebf2facfa0_onEachFeature,
#
#                 style: geo_json_e49be6249977326bfca691ebf2facfa0_styler,
#         });
#
#         function geo_json_e49be6249977326bfca691ebf2facfa0_add (data) {
#             geo_json_e49be6249977326bfca691ebf2facfa0
#                 .addData(data)
#                 .addTo(map_1e3c285748037c431becb0ac08a2a82b);
#         }
#             geo_json_e49be6249977326bfca691ebf2facfa0_add({&quot;bbox&quot;: [-124.53508232338703, 32.13300128241474, -114.61976870231928, 43.342595587931896], &quot;features&quot;: [{&quot;bbox&quot;: [-124.53508232338703, 32.13300128241474, -114.61976870231928, 43.342595587931896], &quot;geometry&quot;: {&quot;coordinates&quot;: [[
quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0cf5fba324b08a788a1c395c86e8cec6 = L.map(
#                 &quot;map_0cf5fba324b08a788a1c395c86e8cec6&quot;,
#                 {
#                     center: [35.90550439, -118.467586],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34f3ab48b134c0ea35cb1fb6467f88a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0cf5fba324b08a788a1c395c86e8cec6);
#
#
#             var marker_11ac71a6689328f6a491043e03f7dfdb = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_0cf5fba324b08a788a1c395c86e8cec6);
#
#
#         var popup_200a76a035427381570d7983ea2ee9cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_747325b50b166dac9e041e64da9021e0 = $(`&lt;div id=&quot;html_747325b50b166dac9e041e64da9021e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_200a76a035427381570d7983ea2ee9cb.setContent(html_747325b50b166dac9e041e64da9021e0);
#
#
#         marker_11ac71a6689328f6a491043e03f7dfdb.bindPopup(popup_200a76a035427381570d7983ea2ee9cb)
#         ;
#
#
#
#
#         function geo_json_17c859d94f942c53674c919ed40b8505_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_17c859d94f942c53674c919ed40b8505_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_17c859d94f942c53674c919ed40b8505 = L.geoJson(null, {
#                 onEachFeature: geo_json_17c859d94f942c53674c919ed40b8505_onEachFeature,
#
#                 style: geo_json_17c859d94f942c53674c919ed40b8505_styler,
#         });
#
#         function geo_json_17c859d94f942c53674c919ed40b8505_add (data) {
#             geo_json_17c859d94f942c53674c919ed40b8505
#                 .addData(data)
#                 .addTo(map_0cf5fba324b08a788a1c395c86e8cec6);
#         }
#             geo_json_17c859d94f942c53674c919ed40b8505_add({&quot;bbox&quot;: [-120.68325542624086, 34.7751650647719, -117.98082431793557, 37.209251477660416], &quot;features&quot;: [{&quot;bbox&quot;: [-120.68325542624086, 34.7751650647719, -117.98082431793557, 37.209251477660416], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.90460829775168, 37.20801503599563], [-118.89969262067598, 37.20919497870216], [-118.89581272901529, 37.20827744537024], [-118.88933723319201, 37.199519659967166], [-118.87724868529415, 37.190985856855434], [-118.87526868217219, 37.18645750477913], [-118.87252592384311, 37.18473922249012], [-118.85684156865915, 37.18380392665824], [-118.85439253741293, 37.18568224436365], [-118.84817253950592, 37.186610089153874], [-118.84248529680644, 37.18119081312062], [-118.83799277181339, 37.18346101207544], [-118.83243616453035, 37.18186970791123], [-118.82732031245496, 37.18283535165972], [-118.82379051766878, 37.17046771313727], [-118.82042253850733, 37.16957718709699], [-118.81736615830374, 37.16638286522692], [-118.81349206976807, 37.166189089185536], [-118.81145608956291, 37.157879362115125], [-118.80807306769316, 37.156761030866846], [-118.80582528644663, 37.153061793372615], [-118.8011610520789, 37.149812696502636], [-118.80138701145353, 37.14847919129636], [-118.79215974688452, 37.1418313381817], [-118.79021985001253, 37.13056326215752], [-118.79282886042517, 37.12542527362382], [-118.79093935313642, 37.12270298196137], [-118.78478424897929, 37.11960423925785], [-118.7769067760749, 37.11972950592434], [-118.77275169587301, 37.11394193718331], [-118.77573170836837, 37.11029263510568], [-118.77486000732807, 37.1088999361495], [-118.7655256646342, 37.10582048927927], [-118.76649927296603, 37.100045903871546], [-118.7514300261144, 37.08937838305479], [-118.74259646154479, 37.08890352576384], [-118.7382293636349, 37.08264951223191], [-118.73841884071794, 37.079428191403565], [-118.72968993448148, 37.08495150701998], [-118.72344069699119, 37.09220634555038], [-118.71922438866443, 37.091525248676476], [-118.71589913866956, 37.094217130963955], [-118.7154378157536, 37.09567401742004], [-118.72281475428383, 37.10008036116318], [-118.71628753554398, 37.106998502819124], [-118.71153950742632, 37.10751272469332], [-118.69958435640325, 37.10459296740618], [-118.68959847412708, 37.10930283198218], [-118.67420150956764, 37.10649057261156], [-118.66950756061658, 37.113995598641566], [-118.67468190435858, 37.12850310799405], [-118.66786543978583, 37.13674054443959], [-118.66321449395969, 37.136

# %%
map_streamgage_watershed(11185500, 8, 8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82db932057954a1320670beeaa855548 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82db932057954a1320670beeaa855548&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_82db932057954a1320670beeaa855548 = L.map(
#                 &quot;map_82db932057954a1320670beeaa855548&quot;,
#                 {
#                     center: [35.90550439, -118.467586],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5c7792d53090c32402db02165248fc4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_82db932057954a1320670beeaa855548);
#
#
#             var marker_759b3251133e54f0e1518449b8fb0caa = L.marker(
#                 [35.90550439, -118.467586],
#                 {&quot;radius&quot;: 10}
#             ).addTo(map_82db932057954a1320670beeaa855548);
#
#
#         var popup_36b083a96f9e9be9a0dc5fe1fbcdba1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_610a624ca1d61a53116e081943686032 = $(`&lt;div id=&quot;html_610a624ca1d61a53116e081943686032&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;11185500 (35.90550439, -118.467586)&lt;/div&gt;`)[0];
#             popup_36b083a96f9e9be9a0dc5fe1fbcdba1e.setContent(html_610a624ca1d61a53116e081943686032);
#
#
#         marker_759b3251133e54f0e1518449b8fb0caa.bindPopup(popup_36b083a96f9e9be9a0dc5fe1fbcdba1e)
#         ;
#
#
#
#
#         function geo_json_0a00d858430ca559ce4e89b3b81b1bcb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_0a00d858430ca559ce4e89b3b81b1bcb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0a00d858430ca559ce4e89b3b81b1bcb = L.geoJson(null, {
#                 onEachFeature: geo_json_0a00d858430ca559ce4e89b3b81b1bcb_onEachFeature,
#
#                 style: geo_json_0a00d858430ca559ce4e89b3b81b1bcb_styler,
#         });
#
#         function geo_json_0a00d858430ca559ce4e89b3b81b1bcb_add (data) {
#             geo_json_0a00d858430ca559ce4e89b3b81b1bcb
#                 .addData(data)
#                 .addTo(map_82db932057954a1320670beeaa855548);
#         }
#             geo_json_0a00d858430ca559ce4e89b3b81b1bcb_add({&quot;bbox&quot;: [-118.64477644919663, 35.637468767600126, -118.20947418737234, 36.70079009928298], &quot;features&quot;: [{&quot;bbox&quot;: [-118.64477644919663, 35.637468767600126, -118.20947418737234, 36.70079009928298], &quot;geometry&quot;: {&quot;coordinates&quot;: [[